# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhi4228/FMML-COURSE-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-16 08:22:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   155MB/s    in 0.4s
#
# 2023-05-16 08:22:19 (155 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 33383   0803.1994v1  Two ideas taken from Bayesian optimization and...    cs
# 37947   1209.3442v3  The seemingly disjoint problems of count and m...  stat
# 2625   1611.09940v3  This paper presents a framework to tackle comb...    cs
# 4366   1606.05589v1  We conduct large-scale studies on `human atten...  stat
# 3564   1712.03999v1  This paper introduces a novel approach to in-p...    cs
# ...             ...                                                ...   ...
# 35290  cs/0307037v1  Modern HENP experiments such as CMS and Atlas ...    cs
# 40836   1408.3944v2  In the field of gestural action recognition, m...    cs
# 29690  1710.01559v1  With an estimated 19 million operations perfor...    cs
# 4882   1610.02164v1  Using current reinforcement learning methods, ...    cs
# 37280  1702.03812v1  The Reservoir Computing (RC) paradigm utilizes...    cs
#
#                                                    title  year  \
# 33383  The Application of Bayesian Optimization and C...  2008
# 37947  Negative Binomial Process Count and Mixture Mo...  2012
# 2625   Neural Combinatorial Optimization with Reinfor...  2016
# 4366   Human Attention in Visual Question Answering: ...  2016
# 3564   Eye In-Painting with Exemplar Generative Adver...  2017
# ...                                                  ...   ...
# 35290  Supporting Dynamic Ad hoc Collaboration Capabi...  2003
# 40836  Down-Sampling coupled to Elastic Kernel Machin...  2014
# 29690  Monitoring tool usage in cataract surgery vide...  2017
# 4882   Deep Reinforcement Learning From Raw Pixels in...  2016
# 37280  Reservoir Computing Using Non-Uniform Binary C...  2017
#
#                                                 keywords
# 33383  [optimization, classifier, presented, personne...
# 37947  [seemingly, normalization, probability, margin...
# 2625   [framework, combinatorial, optimization, reinf...
# 4366   [attention, answering, understand, questions, ...
# 3564   [introduces, preserved, accounted, inference, ...
# ...                                                  ...
# 35290  [experiments, collaborators, collaborations, c...
# 40836  [recognition, dimensionality, reduction, varia...
# 29690  [estimated, operations, performed, procedure, ...
# 4882   [reinforcement, challenges, environments, summ...
# 37280  [reservoir, computing, dynamical, reservoir, c...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 33383    [optimization, classifier, presented, personne...
# 37947    [seemingly, normalization, probability, margin...
# 2625     [framework, combinatorial, optimization, reinf...
# 4366     [attention, answering, understand, questions, ...
# 3564     [introduces, preserved, accounted, inference, ...
#                                ...
# 34359    [increased, information, available, understand...
# 30823    [nonlinear, registration, histological, corres...
# 23168    [translation, stereoscopic, homologous, method...
# 22247    [extracting, dimensional, structure, dimension...
# 36977    [persuasive, teachable, teachable, incorporate...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8701 words.
# Out of those 4596 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="f815a8f8-40da-4971-93ff-449bdd925e5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f815a8f8-40da-4971-93ff-449bdd925e5a")) {                    Plotly.newPlot(                        "f815a8f8-40da-4971-93ff-449bdd925e5a",                        [{"x":["assignment","usefulness","distribution","according","presented","constantly","application","construct","algorithm","suggested","instances","probability","solutions","personnel","algorithms","optimization","scheduling","situation","approaches","classifier","demonstrate","mechanism","computational","respectively","hierarchical","fundamental","normalization","processes","marginalization","bivariate","relationships","geometric","properties","importance","dirichlet","augmentation","inferring","highlight","seemingly","distributed","logarithmic","connections","constructed","parameters","inference","restaurant","associated","structural","efficient","dispersion","distributions","developed","advantages","mechanisms","theoretical","including","combinatorial","individual","permutations","designing","different","heuristic","traveling","engineering","reinforcement","coordinates","euclidean","recurrent","framework","introduce","interfaces","generated","answering","attention","qualitatively","experiments","understand","questions","quantitatively","annotation","benchmark","introduces","reference","personalized","comparisons","semantically","plausible","preserved","formulations","information","introduced","accounted","conditional","perceptually","adversarial","perceptual","describing","generative","descriptive","increasing","realistic","numerical","communication","topologies","bottleneck","reduction","representations","publications","dependent","accelerators","experimental","precision","implementations","available","transparent","quantization","simulation","evaluation","gradients","trainingtest","tensorflow","significant","improvement","prevalent","recovering","coordination","structures","syntactic","prediction","representation","statistical","impressive","affecting","neighborhood","posteriori","computationally","denoising","competitive","functions","efficiently","applications","tractability","intractable","exponentially","requirement","advantage","structure","phenomenon","specifically","exhaustive","performance","generation","incorporation","unsupervised","additional","independent","candidate","embedding","explicitly","improving","formation","character","trainable","unfolding","constructs","discovery","combining","background","stochastic","benchmarks","favorable","relational","described","corresponding","reflecting","architecture","knowledge","handcrafted","classification","investigate","carefully","convolutional","interpreted","retrieval","aggregation","evaluated","providing","aggregating","traditional","similarities","descriptors","engineered","particular","activations","considerably","aggregated","descriptor","aggregate","overfitting","artificial"],"y":[23,24,209,91,188,4,242,100,837,20,107,162,134,3,581,301,16,37,434,164,528,123,274,87,120,77,30,102,4,1,70,73,199,92,16,36,23,27,2,95,16,56,69,246,201,2,101,68,413,3,124,197,84,38,159,256,35,116,2,44,754,61,7,43,118,13,36,168,575,330,15,163,49,160,13,603,55,63,18,62,231,85,55,14,36,36,18,12,20,735,119,4,119,9,116,24,41,114,17,87,59,94,65,15,22,94,238,8,64,3,379,72,36,318,5,18,80,268,32,2,6,244,149,4,20,13,130,63,244,355,167,17,15,34,7,85,40,143,194,144,425,16,21,20,33,94,327,19,166,17,888,153,15,152,111,126,51,101,80,117,15,55,20,3,23,44,113,78,124,96,8,42,64,144,7,254,356,17,525,135,32,392,24,102,22,154,81,17,194,42,41,10,264,15,25,16,34,19,22,117],"type":"bar"},{"x":["assignment","usefulness","distribution","according","presented","constantly","a ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4596,), (4596, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Lower</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>Lifted</span> <span style='background-color:rgba(255, 0, 0, 0.3420621931260228);'>Inference</span> <br/><br/><span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>big</span> <span style='background-color:rgba(0, 255, 0, 0.3099415204678362);'>challenges</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4131736526946109);'>development</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>relational</span> <span style=''>(or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>logical)</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frameworks</span> <span style=''>is</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3420621931260228);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>that</span> <span style=''>operate</span> <span style=''>on</span> <span style=''>the</span> <span style=''>level</span> <span style=''>of</span> <span style=''>the</span> <span style=''>abstract</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3575525812619504);'>representation</span> <span style=''>language</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>on</span> <span style=''>the</span> <span style=''>level</span> <span style=''>of</span> <span style=''>ground</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style='background-color:rgba(0, 255, 0, 0.3630573248407643);'>instances</span> <span style=''>of</span> <span style=''>the</span> <span style=''>model</span> <span style=''>Numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>for</span> <span style=''>such</span> <span style=''>lifted</span> <span style='background-color:rgba(255, 0, 0, 0.3420621931260228);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>While</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>will</span> <span style=''>lead</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3420621931260228);'>inference</span> <span style=''>on</span> <span style=''>some</span> <span style=''>specific</span> <span style=''>models</span> <span style=''>there</span> <span style=''>are</span> <span style=''>only</span> <span style=''>very</span> <span style=''>recent</span> <span style=''>and</span> <span style=''>still</span> <span style=''>quite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>results</span> <span style=''>that</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6296296296296297);'>feasibility</span> <span style=''>of</span> <span style=''>lifted</span> <span style='background-color:rgba(255, 0, 0, 0.3420621931260228);'>inference</span> <span style=''>on</span> <span style=''>certain</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>in</span> <span style=''>Graphs</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoregressive</span> <span style=''>Features</span> <br/><br/><span style=''>In</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>in</span> <span style=''>time</span> <span style=''>evolving</span> <span style=''>graphs</span> <span style=''>We</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>certain</span> <span style=''>graph</span> <span style=''>features</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>node</span> <span style=''>degree</span> <span style=''>follow</span> <span style=''>a</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>(VAR)</span> <span style=''>model</span> <span style=''>and</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>use</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>Our</span> <span style=''>strategy</span> <span style=''>involves</span> <span style=''>a</span> <span style=''>joint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>over</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrices</span> <span style=''>and</span> <span style=''>VAR</span> <span style=''>matrices</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>into</span> <span style=''>account</span> <span style=''>both</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>matrices</span> <span style=''>Oracle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inequalities</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>the</span> <span style=''>trade</span> <span style=''>offs</span> <span style=''>in</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>smoothing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>when</span> <span style=''>modeling</span> <span style=''>the</span> <span style=''>joint</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>property</span> <span style=''>The</span> <span style=''>estimate</span> <span style=''>is</span> <span style=''>computed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>using</span> <span style=''>proximal</span> <span style=''>methods</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>forward</span> <span style=''>backward</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Recovery</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Guarantee</span> <span style=''>of</span> <span style=''>Non</span> <span style=''>negative</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Factorization</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Alternating</span> <span style=''>Updates</span> <br/><br/><span style=''>Non</span> <span style=''>negative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorization</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposing</span> <span style=''>data</span> <span style=''>into</span> <span style=''>feature</span> <span style=''>and</span> <span style=''>weight</span> <span style=''>matrices</span> <span style=''>under</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>negativity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>It</span> <span style=''>enjoys</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>success</span> <span style=''>but</span> <span style=''>is</span> <span style=''>poorly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style='background-color:rgba(255, 0, 0, 0.3541666666666666);'>theoretically</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternates</span> <span style=''>between</span> <span style=''>decoding</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>updating</span> <span style=''>the</span> <span style=''>features</span> <span style=''>and</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>assuming</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>it</span> <span style=''>provably</span> <span style=''>recovers</span> <span style=''>the</span> <span style=''>ground</span> <span style=''>truth</span> <span style=''>under</span> <span style=''>fairly</span> <span style=''>mild</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>its</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.47457627118644075);'>essential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirement</span> <span style=''>on</span> <span style=''>features</span> <span style=''>is</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3809523809523809);'>independence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>uses</span> <span style=''>ReLU</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>negativity</span> <span style=''>for</span> <span style=''>decoding</span> <span style=''>the</span> <span style=''>weights</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>can</span> <span style=''>tolerate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarial</span> <span style=''>noise</span> <span style=''>that</span> <span style=''>c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Evaluation</span> <span style=''>of</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>Methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>usually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>by</span> <span style=''>wrapping</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>datasets</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>very</span> <span style=''>often</span> <span style=''>in</span> <span style=''>unfair</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>between</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>obtaining</span> <span style=''>the</span> <span style=''>true</span> <span style=''>feature</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>forward</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>entropy</span> <span style=''>or</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>or</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style=''>undoubtful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>Moreover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>unveils</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>to</span> <span style=''>some</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>namely</span> <span style='background-color:rgba(255, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12619978670458584)
# 	processing (0.09669392108069677)
# 	knowledge (0.1265552790615002)
# 	architecture (0.0902950586562389)
# 	segmentation (0.07465339495200853)
# 	information (0.26128688233202985)
# 	detection (0.12513330963384287)
# 	different (0.26804123711340205)
# 	convolutional (0.1393530039104159)
# 	recognition (0.1453963739779595)
#
# Some Statistics words are:
# 	stochastic (0.13236034222445897)
# 	variables (0.13487669854051335)
# 	variational (0.10669350780070458)
# 	algorithm (0.3910417715148465)
# 	theoretical (0.1540010065425264)
# 	estimation (0.1766482133870156)
# 	distribution (0.18369401107196778)
# 	dimensional (0.18570709612481126)
# 	inference (0.20634121791645696)
# 	regression (0.18822345244086564)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="e62ec891-880c-4194-8b3d-d433b4d7b2d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e62ec891-880c-4194-8b3d-d433b4d7b2d5")) {                    Plotly.newPlot(                        "e62ec891-880c-4194-8b3d-d433b4d7b2d5",                        [{"x":["assignment","usefulness","distribution","according","presented","constantly","application","construct","algorithm","suggested","instances","probability","solutions","personnel","algorithms","optimization","scheduling","situation","approaches","classifier","demonstrate","mechanism","computational","respectively","hierarchical","fundamental","normalization","processes","marginalization","bivariate","relationships","geometric","properties","importance","dirichlet","augmentation","inferring","highlight","seemingly","distributed","logarithmic","connections","constructed","parameters","inference","restaurant","associated","structural","efficient","dispersion","distributions","developed","advantages","mechanisms","theoretical","including","combinatorial","individual","permutations","designing","different","heuristic","traveling","engineering","reinforcement","coordinates","euclidean","recurrent","framework","introduce","interfaces","generated","answering","attention","qualitatively","experiments","understand","questions","quantitatively","annotation","benchmark","introduces","reference","personalized","comparisons","semantically","plausible","preserved","formulations","information","introduced","accounted","conditional","perceptually","adversarial","perceptual","describing","generative","descriptive","increasing","realistic","numerical","communication","topologies","bottleneck","reduction","representations","publications","dependent","accelerators","experimental","precision","implementations","available","transparent","quantization","simulation","evaluation","gradients","trainingtest","tensorflow","significant","improvement","prevalent","recovering","coordination","structures","syntactic","prediction","representation","statistical","impressive","affecting","neighborhood","posteriori","computationally","denoising","competitive","functions","efficiently","applications","tractability","intractable","exponentially","requirement","advantage","structure","phenomenon","specifically","exhaustive","performance","generation","incorporation","unsupervised","additional","independent","candidate","embedding","explicitly","improving","formation","character","trainable","unfolding","constructs","discovery","combining","background","stochastic","benchmarks","favorable","relational","described","corresponding","reflecting","architecture","knowledge","handcrafted","classification","investigate","carefully","convolutional","interpreted","retrieval","aggregation","evaluated","providing","aggregating","traditional","similarities","descriptors","engineered","particular","activations","considerably","aggregated","descriptor","aggregate","overfitting","artificial","additionally","dynamically","specialized","systematically","categories","transformations","comparable","strategies","resulting","methodology","motivated","classical","illustrate","statistics","implemented","extension","configurations","elementary","sequential","probabilistic","triggered","accumulated","formulation","multiplayer","attribute","weaknesses","combinations","predicting","regression","progresses","introducing","variation","integrated","contribution","challenge","alternative","estimation","extensions","variations","international","successful","pipelines","compromise","stochastically","identical","regarding","partially","exploration","secondary","opportunistic","exploitation","requirements","characteristics","subgraphs","tractable","empirically ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	multiplayer
# 	precludes
# 	nonconjugate
# 	forecasters
# 	sridharan
# 	approachability
# 	martingale
# 	forecasts
# 	uncovering
# 	climatology
# 	quantiles
# 	supermarket
# 	sinusoidal
# 	pharmacokinetic
# 	epidemiology
# 	confounders
# 	particulars
# 	diminishing
# 	unintentionally
# 	correspondingly
# Some words which never appear in Statistics papers:
# 	constantly
# 	personnel
# 	traveling
# 	perceptually
# 	accelerators
# 	trainingtest
# 	syntactic
# 	inapproximability
# 	compensate
# 	utterance
# 	conversations
# 	telephone
# 	acoustically
# 	histopathological
# 	continues
# 	photometric
# 	illumination
# 	engineers
# 	evidences
# 	underwater

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0556743873372856e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7425
